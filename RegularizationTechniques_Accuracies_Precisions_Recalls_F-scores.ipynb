# %%
# import necessary libraries
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# define the paths to the train and test folders on your desktop
train_path = 'C:/Users/chand/Desktop/New folder/DeepLearning/Dataset/train'
test_path = 'C:/Users/chand/Desktop/New folder/DeepLearning/Dataset/test'

# define image and batch size
img_height, img_width = 28, 28
batch_size = 64

# create ImageDataGenerator objects for data augmentation
train_datagen = ImageDataGenerator(
    rescale=1.0/255.0,
    rotation_range=20,
    zoom_range=0.2,
    shear_range=0.2,
    width_shift_range=0.2,
    height_shift_range=0.2,
    horizontal_flip=False,
    vertical_flip=False,
    fill_mode='nearest'
)

test_datagen = ImageDataGenerator(
    rescale=1.0/255.0
)

# create flow_from_directory generators for train and test datasets
train_generator = train_datagen.flow_from_directory(
    directory=train_path,
    target_size=(img_height, img_width),
    color_mode="grayscale",
    batch_size=batch_size,
    class_mode="categorical",
    shuffle=True,
    seed=42
)

test_generator = test_datagen.flow_from_directory(
    directory=test_path,
    target_size=(img_height, img_width),
    color_mode="grayscale",
    batch_size=batch_size,
    class_mode="categorical",
    shuffle=False,
    seed=42
)

# define the model architecture
model = keras.Sequential(
    [
        keras.Input(shape=(img_height, img_width, 1)),
        layers.Conv2D(32, kernel_size=(3, 3), activation="relu"),
        layers.MaxPooling2D(pool_size=(2, 2)),
        layers.Flatten(),
        layers.Dense(128, activation="relu"),
        layers.Dense(train_generator.num_classes, activation="softmax"),
    ]
)

# compile the model
model.compile(optimizer="adam", loss="categorical_crossentropy", metrics=["accuracy"])

# train the model
# MODEL.summary

history = model.fit(train_generator, epochs=10, validation_data=test_generator)

# evaluate the model on test set
test_loss, test_acc = model.evaluate(test_generator, verbose=2)
print("Test accuracy:", test_acc)
# Out:
# Found 17000 images belonging to 10 classes.
# Found 2999 images belonging to 10 classes.
# Epoch 1/10
# 266/266 [==============================] - 32s 117ms/step - loss: 1.1092 - accuracy: 0.6325 - val_loss: 0.2267 - val_accuracy: 0.9423
# Epoch 2/10
# 266/266 [==============================] - 20s 74ms/step - loss: 0.5117 - accuracy: 0.8375 - val_loss: 0.1389 - val_accuracy: 0.9647
# Epoch 3/10
# 266/266 [==============================] - 18s 69ms/step - loss: 0.3784 - accuracy: 0.8775 - val_loss: 0.1116 - val_accuracy: 0.9657
# Epoch 4/10
# 266/266 [==============================] - 17s 65ms/step - loss: 0.3059 - accuracy: 0.9050 - val_loss: 0.0962 - val_accuracy: 0.9697
# Epoch 5/10
# 266/266 [==============================] - 18s 66ms/step - loss: 0.2720 - accuracy: 0.9164 - val_loss: 0.0870 - val_accuracy: 0.9763
# Epoch 6/10
# 266/266 [==============================] - 18s 66ms/step - loss: 0.2359 - accuracy: 0.9256 - val_loss: 0.0710 - val_accuracy: 0.9797
# Epoch 7/10
# 266/266 [==============================] - 20s 77ms/step - loss: 0.2132 - accuracy: 0.9339 - val_loss: 0.0559 - val_accuracy: 0.9817
# Epoch 8/10
# 266/266 [==============================] - 18s 67ms/step - loss: 0.1949 - accuracy: 0.9388 - val_loss: 0.0581 - val_accuracy: 0.9820
# Epoch 9/10
# 266/266 [==============================] - 17s 66ms/step - loss: 0.1761 - accuracy: 0.9462 - val_loss: 0.0544 - val_accuracy: 0.9867
# Epoch 10/10
# 266/266 [==============================] - 18s 66ms/step - loss: 0.1695 - accuracy: 0.9470 - val_loss: 0.0415 - val_accuracy: 0.9880
# 47/47 - 1s - loss: 0.0415 - accuracy: 0.9880 - 1s/epoch - 28ms/step
# Test accuracy: 0.987995982170105

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.regularizers import l2

# define the paths to the train and test folders on your desktop
train_path = 'C:/Users/chand/Desktop/New folder/DeepLearning/Dataset/train'
test_path = 'C:/Users/chand/Desktop/New folder/DeepLearning/Dataset/test'

# define image and batch size
img_height, img_width = 28, 28
batch_size = 64

# create ImageDataGenerator objects for data augmentation
train_datagen = ImageDataGenerator(
    rescale=1.0/255.0,
    rotation_range=20,
    zoom_range=0.2,
    shear_range=0.2,
    width_shift_range=0.2,
    height_shift_range=0.2,
    horizontal_flip=False,
    vertical_flip=False,
    fill_mode='nearest'
)

test_datagen = ImageDataGenerator(
    rescale=1.0/255.0
)

# create flow_from_directory generators for train and test datasets
train_generator = train_datagen.flow_from_directory(
    directory=train_path,
    target_size=(img_height, img_width),
    color_mode="grayscale",
    batch_size=batch_size,
    class_mode="categorical",
    shuffle=True,
    seed=42
)

test_generator = test_datagen.flow_from_directory(
    directory=test_path,
    target_size=(img_height, img_width),
    color_mode="grayscale",
    batch_size=batch_size,
    class_mode="categorical",
    shuffle=False,
    seed=42
)

# define the model architecture
model = keras.Sequential(
    [
        keras.Input(shape=(img_height, img_width, 1)),
        layers.Conv2D(32, kernel_size=(3, 3), activation="relu"),
        layers.MaxPooling2D(pool_size=(2, 2)),
        layers.Dropout(0.25),
        layers.Conv2D(64, kernel_size=(3, 3), activation="relu", kernel_regularizer=l2(0.01)),
        layers.MaxPooling2D(pool_size=(2, 2)),
        layers.Dropout(0.25),
        layers.Flatten(),
        layers.Dense(128, activation="relu", kernel_regularizer=l2(0.01)),
        layers.Dropout(0.5),
        layers.Dense(train_generator.num_classes, activation="softmax"),
    ]
)

# compile the model
model.compile(optimizer="adam", loss="categorical_crossentropy", metrics=["accuracy", tf.keras.metrics.Precision(), tf.keras.metrics.Recall()])

# train the model
history = model.fit(train_generator, epochs=10, validation_data=test_generator)

# evaluate the model on test set
test_loss, test_acc, test_precision, test_recall = model.evaluate(test_generator, verbose=2)
print("Test accuracy:", test_acc)
print("Test precision:", test_precision)
print("Test recall:", test_recall)
# Out:
# Found 17000 images belonging to 10 classes.
# Found 2999 images belonging to 10 classes.
# Epoch 1/10
# 266/266 [==============================] - 18s 64ms/step - loss: 2.2570 - accuracy: 0.4155 - precision: 0.7398 - recall: 0.1657 - val_loss: 0.8004 - val_accuracy: 0.9043 - val_precision: 0.9643 - val_recall: 0.7919
# Epoch 2/10
# 266/266 [==============================] - 16s 59ms/step - loss: 1.4925 - accuracy: 0.6189 - precision: 0.8003 - recall: 0.4245 - val_loss: 0.6561 - val_accuracy: 0.9280 - val_precision: 0.9663 - val_recall: 0.8610
# Epoch 3/10
# 266/266 [==============================] - 16s 61ms/step - loss: 1.3258 - accuracy: 0.6701 - precision: 0.8146 - recall: 0.5132 - val_loss: 0.6088 - val_accuracy: 0.9416 - val_precision: 0.9715 - val_recall: 0.8873
# Epoch 4/10
# 266/266 [==============================] - 19s 72ms/step - loss: 1.2721 - accuracy: 0.6890 - precision: 0.8187 - recall: 0.5431 - val_loss: 0.5554 - val_accuracy: 0.9560 - val_precision: 0.9776 - val_recall: 0.9153
# Epoch 5/10
# 266/266 [==============================] - 30s 113ms/step - loss: 1.2109 - accuracy: 0.7089 - precision: 0.8314 - recall: 0.5756 - val_loss: 0.5288 - val_accuracy: 0.9553 - val_precision: 0.9737 - val_recall: 0.9276
# Epoch 6/10
# 266/266 [==============================] - 25s 94ms/step - loss: 1.1799 - accuracy: 0.7119 - precision: 0.8290 - recall: 0.5906 - val_loss: 0.5111 - val_accuracy: 0.9483 - val_precision: 0.9741 - val_recall: 0.9266
# Epoch 7/10
# 266/266 [==============================] - 23s 85ms/step - loss: 1.1607 - accuracy: 0.7191 - precision: 0.8326 - recall: 0.6020 - val_loss: 0.5047 - val_accuracy: 0.9620 - val_precision: 0.9746 - val_recall: 0.9336
# Epoch 8/10
# 266/266 [==============================] - 29s 109ms/step - loss: 1.1388 - accuracy: 0.7296 - precision: 0.8363 - recall: 0.6145 - val_loss: 0.4969 - val_accuracy: 0.9597 - val_precision: 0.9767 - val_recall: 0.9353
# Epoch 9/10
# 266/266 [==============================] - 29s 109ms/step - loss: 1.1120 - accuracy: 0.7374 - precision: 0.8392 - recall: 0.6243 - val_loss: 0.5021 - val_accuracy: 0.9623 - val_precision: 0.9791 - val_recall: 0.9350
# Epoch 10/10
# 266/266 [==============================] - 20s 76ms/step - loss: 1.0795 - accuracy: 0.7462 - precision: 0.8443 - recall: 0.6441 - val_loss: 0.4670 - val_accuracy: 0.9623 - val_precision: 0.9760 - val_recall: 0.9476
# 47/47 - 1s - loss: 0.4670 - accuracy: 0.9623 - precision: 0.9760 - recall: 0.9476 - 1s/epoch - 30ms/step
# Test accuracy: 0.9623207449913025
# Test precision: 0.9759615659713745
# Test recall: 0.9476492404937744
